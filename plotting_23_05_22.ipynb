# %% [markdown]
# <a href="https://colab.research.google.com/github/pmogili/python-new/blob/main/plotting_23_05_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([-6, 60])
ypoints = np.array([-25, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import unittest
def oneD_to_sorted2D(lst):
  lst.sort()
  t = []
  p = []
  for i in range(0,len(lst)):
    t.append(lst[i])
    if (i+1)%3==0:
      p.append(t)
      t = []
   return p
# Out:
#   File "<ipython-input-1-429267f25ddc>", line 11
#     return p
#                ^
# IndentationError: unindent does not match any outer indentation level

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["clad", "single variable", "several variable", "vdec"])
y = np.array([9, 60, 93 , 55])

plt.bar(x,y, color="grey")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["clad", "single variable", "several variable", "vdec"])
y = np.array([9, 60, 93 , 55])

plt.bar(x,y, width=1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([5, 20,20 ,50,5])
mylabels = ["captain america", "thor", "hulk", "iron man" ,"hawkeye"]

plt.pie(y, labels = mylabels)
plt.legend(title = "avengers:")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(17, 10, 25)

plt.hist(x,color="purple")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y ,color="black")
plt.show()
